# %% [markdown]
# ## Objective
#
# See if we can get the model working first. We will run the mini model.

# %%
# !git clone https://github.com/kwsong0113/diffusion-forcing-transformer.git
# Out:
# Cloning into 'diffusion-forcing-transformer'...
# remote: Enumerating objects: 290, done.
# remote: Counting objects: 100% (290/290), done.
# remote: Compressing objects: 100% (244/244), done.
# remote: Total 290 (delta 50), reused 275 (delta 37), pack-reused 0 (from 0)
# Receiving objects: 100% (290/290), 1.76 MiB | 35.41 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
import os
os.chdir('/content/diffusion-forcing-transformer')

# %% [markdown]
# I also ran on the T4 which is pretty slow we can try A100 but be warned that A100 is very expensive so only use it if you really want to try something.
# Before moving on before you go into the configurations file and change the argument to your Weights and Biases. Make sure you create an account here. CHANGE THE PARAMETER IN THE CONFIG FILE TO YOUR FULL USERNAME> MINE IS azpeer-massachusetts-institute-of-technology. We will create a team project soon. Basically, WandB is used for expirement tracking and seems cool just hella gay to get running but not bad. Also create a new project and call this dfot.
#
# https://wandb.ai/
#
# The below line logs you into the account.
#
# `!wandb login`
#
# This requires an API key. You get this from above link. Just click on the project.
#
# Also when you run the
#
# `!pip install -r requirements.txt`
#
# You will get a warning / error that it can't install numpy and it will tell you to restart the kernerl. Just click restart and rerun the pip install line. Idk wtf is going on but fuck it you know.
#
# Ok so super good news. This shit works. Bad news, the shit runs hella examples and I just tried running it on the short video frame. The next steps is going to the github link
#
# https://github.com/kwsong0113/diffusion-forcing-transformer/tree/main?tab=readme-ov-file
#
# and all going through there tutorial. Also need to research CLIP and have one of us throroughly read the paper to analyze specificall how they use classifier free guidance to actually figure out how to embedd the embeddings from the CLIP encoder to the model. Some raw ideas from just intution.
#
# (1) Take that shit the old school way.
#   - We fucking look at their data set and manually label shit
#   - then we refintetune with some type of new loss
#
# (2) We try sticking the embeddings in the adaptive norm layer from the ideas presented in how they used to diffusion.
#   - This ideas is from the lecture of 4/22

# %%
# set exvironment variables
os.environ["WANDB_ENTITY"] = "azpeer-massachusetts-institute-of-technology"
os.environ["WANDB_PROJECT"] = "dfot"

# %%
# !pip install -r requirements.txt

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: azpeer (azpeer-massachusetts-institute-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
# !python -m main +name=single_image_to_short dataset=realestate10k_mini algorithm=dfot_video_pose experiment=video_generation @diffusion/continuous load=pretrained:DFoT_RE10K.ckpt 'experiment.tasks=[validation]' experiment.validation.data.shuffle=True dataset.context_length=1 dataset.frame_skip=20 dataset.n_frames=8 experiment.validation.batch_size=1 algorithm.tasks.prediction.history_guidance.name=vanilla +algorithm.tasks.prediction.history_guidance.guidance_scale=4.0
# Out:
# 2025-04-23 14:46:13.103360: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745419573.122423    2982 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745419573.128667    2982 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-23 14:46:13.148894: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
